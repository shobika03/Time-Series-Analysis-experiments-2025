# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dates=pd.date_range(start="2025-02-01",end="2025-02-10",freq="D")

# %%
data={
    'Date':dates,
    'Temperature':[22.1, 23.4, np.nan, 25.6, np.nan, 27.3, 29.4, np.nan, 31.0, 32.5],
    'Humidity':[60, 62, 64, np.nan, 69, np.nan, 72, 75, np.nan, 79]
}
df=pd.DataFrame(data)

# %%
df.set_index('Date',inplace=True)

# %%
print(df)
# Out:
#             Temperature  Humidity
# Date
# 2025-02-01         22.1      60.0
# 2025-02-02         23.4      62.0
# 2025-02-03          NaN      64.0
# 2025-02-04         25.6       NaN
# 2025-02-05          NaN      69.0
# 2025-02-06         27.3       NaN
# 2025-02-07         29.4      72.0
# 2025-02-08          NaN      75.0
# 2025-02-09         31.0       NaN
# 2025-02-10         32.5      79.0

# %%
df_interpolated = df.interpolate(method='linear')
plt.figure(figsize=(12, 6))

# %%
plt.plot(df.index, df['Temperature'], label='Original Temperature', marker='o', color='green', linestyle='-', alpha=0.6, markersize=8)
plt.plot(df.index, df['Humidity'], label='Original Humidity', marker='o', color='red', linestyle='-', alpha=0.6, markersize=8)
plt.title('Original Time Series Data with Missing Values')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df_interpolated['Temperature'], label='Interpolated Temperature', marker='o', color='blue', linestyle='-', markersize=6)
plt.plot(df.index, df_interpolated['Humidity'], label='Interpolated Humidity', marker='o', color='red', linestyle='-', markersize=6)
plt.title('Interpolated Time Series Data (After Interpolation)')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
